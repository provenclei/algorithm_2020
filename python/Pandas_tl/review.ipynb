# %%
# %config ZMQInteractiveShell.ast_node_interactivity='all'
# %pprint
import numpy as np
# Out:
# Pretty printing has been turned OFF

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.25.1'

# %%
np.random.random((5,))

np.random.random((5,4))

np.random.randn(5)
# Out:
# array([0.4200114 , 0.96541558, 0.91024572, 0.77470086, 0.27873987])
# array([[0.82325263, 0.57240635, 0.66340728, 0.05907748],
#        [0.24668937, 0.24330879, 0.83718337, 0.78667937],
#        [0.97403081, 0.84447679, 0.52966072, 0.0097991 ],
#        [0.55647548, 0.58719173, 0.63015852, 0.15724806],
#        [0.22322168, 0.66476046, 0.46999852, 0.45632584]])
# array([-1.88481409, -0.68409077,  1.85019141, -0.52529549, -1.21101   ])

# %%
# 正态分布
np.random.randn(5)
# Out:
# array([ 0.38978239,  0.29075777, -0.57655589, -1.73702644,  1.67501492])

# %%
# 0,1之间的浮点数
np.random.random((2,2))
# Out:
# array([[0.33967517, 0.96956106],
#        [0.13590794, 0.4565517 ]])

# %%
# [0,1)
np.random.rand(5)
# Out:
# array([0.89559407, 0.51217993, 0.84886525, 0.3304502 , 0.08398154])

# %%
# 使用字典构建Dataframe
data = {'city': ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Hangzhou', 'Chongqing'],
       'year': [2016,2017,2016,2017,2016, 2016],
       'population': [2100, 2300, 1000, 700, 500, 500]}
pd.DataFrame(data)
# Out:
#         city  year  population
# 0    Beijing  2016        2100
# 1   Shanghai  2017        2300
# 2  Guangzhou  2016        1000
# 3   Shenzhen  2017         700
# 4   Hangzhou  2016         500
# 5  Chongqing  2016         500

# %%
# 使用series构建dataframe
cities = {'Beijing': 55000, 'Shanghai': 60000, 'Shenzhen': 50000, 'Hangzhou': 20000, 'Guangzhou': 25000, 'Suzhou': None}
apts = pd.Series(cities, name="price")
apts

cars = pd.Series({'Beijing': 300000, 'Shanghai': 400000, 'Shenzhen': 300000, \
                      'Tianjin': 200000, 'Guangzhou': 200000, 'Chongqing': 150000}, name="popularity")
cars

df = pd.DataFrame({'apts':apts, 'cars':cars})
df
# Out:
# Beijing      55000.0
# Shanghai     60000.0
# Shenzhen     50000.0
# Hangzhou     20000.0
# Guangzhou    25000.0
# Suzhou           NaN
# Name: price, dtype: float64
# Beijing      300000
# Shanghai     400000
# Shenzhen     300000
# Tianjin      200000
# Guangzhou    200000
# Chongqing    150000
# Name: popularity, dtype: int64
#               apts      cars
# Beijing    55000.0  300000.0
# Chongqing      NaN  150000.0
# Guangzhou  25000.0  200000.0
# Hangzhou   20000.0       NaN
# Shanghai   60000.0  400000.0
# Shenzhen   50000.0  300000.0
# Suzhou         NaN       NaN
# Tianjin        NaN  200000.0

# %%
# 使用 list of dicts来构建DataFrame
data = [{"BOSS": 999999, "Jason": 50000, "Han": 1000}, \
        {"BOSS": 99999, "Jason": 8000, "Han": 200}]
pd.DataFrame(data,columns=['BOSS','Han','Jason'])
# Out:
#      BOSS   Han  Jason
# 0  999999  1000  50000
# 1   99999   200   8000

# %%
df["total_cost"] = df["apts"]*100 + df["cars"]
df
# Out:
#               apts      cars  total_cost
# Beijing    55000.0  300000.0   5800000.0
# Chongqing      NaN  150000.0         NaN
# Guangzhou  25000.0  200000.0   2700000.0
# Hangzhou   20000.0       NaN         NaN
# Shanghai   60000.0  400000.0   6400000.0
# Shenzhen   50000.0  300000.0   5300000.0
# Suzhou         NaN       NaN         NaN
# Tianjin        NaN  200000.0         NaN

# %%
data = {'city': ['Beijing', 'Shanghai', 'Guangzhou', 'Shenzhen', 'Hangzhou', 'Chongqing'],
       'year': [2016,2017,2016,2017,2016, 2016],
       'population': [2100, 2300, 1000, 700, 500, 500]}
frame = pd.DataFrame(data, columns = ['year', 'city', 'population'],
                     index = ['one', 'two', 'three', 'four', 'five', 'six'])
frame
# Out:
#        year       city  population
# one    2016    Beijing        2100
# two    2017   Shanghai        2300
# three  2016  Guangzhou        1000
# four   2017   Shenzhen         700
# five   2016   Hangzhou         500
# six    2016  Chongqing         500

# %%
frame['city']
type(frame['city'])

frame[['city']] # DataFrame
type(frame[['city']])
# Out:
# one        Beijing
# two       Shanghai
# three    Guangzhou
# four      Shenzhen
# five      Hangzhou
# six      Chongqing
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>
#             city
# one      Beijing
# two     Shanghai
# three  Guangzhou
# four    Shenzhen
# five    Hangzhou
# six    Chongqing
# <class 'pandas.core.frame.DataFrame'>

# %%
# 只能切片
frame.iloc[1:4, 2:3]
# Out:
#        population
# two          2300
# three        1000
# four          700

# %%
# 既能切片，又能索引
frame.loc[:, 'city']
# Out:
# one        Beijing
# two       Shanghai
# three    Guangzhou
# four      Shenzhen
# five      Hangzhou
# six      Chongqing
# Name: city, dtype: object

# %%
# 我们可以给定多个条件进行组合，选择对应的数据。每个条件用小括号包裹，同时通过&(与) |(或) ~(非)进行组合。
frame

frame.loc[(frame['year']==2016)|(frame['population']>=1000), ['year','population']]
# Out:
#        year       city  population
# one    2016    Beijing        2100
# two    2017   Shanghai        2300
# three  2016  Guangzhou        1000
# four   2017   Shenzhen         700
# five   2016   Hangzhou         500
# six    2016  Chongqing         500
#        year  population
# one    2016        2100
# two    2017        2300
# three  2016        1000
# five   2016         500
# six    2016         500

# %%
# 但是这种方式会覆盖Series中
val = pd.Series([100, 200, 300], index=['two', 'three', 'five'])
frame['debt'] = val
print(frame)
# Out:
#        year       city  population   debt
# one    2016    Beijing        2100    NaN
# two    2017   Shanghai        2300  100.0
# three  2016  Guangzhou        1000  200.0
# four   2017   Shenzhen         700    NaN
# five   2016   Hangzhou         500  300.0
# six    2016  Chongqing         500    NaN

# %%
frame.index

frame.T

frame.columns
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')
#                 one       two      three      four      five        six
# year           2016      2017       2016      2017      2016       2016
# city        Beijing  Shanghai  Guangzhou  Shenzhen  Hangzhou  Chongqing
# population     2100      2300       1000       700       500        500
# debt            NaN       100        200       NaN       300        NaN
# Index(['year', 'city', 'population', 'debt'], dtype='object')

# %%
# read CSV
pokemon = pd.read_csv("./data/Pokemon.csv")
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# 写入数据 重复写入会覆盖数据
pokemon.loc[:50,['HP','Defense']].to_csv('./data/pokemon_tmp.csv')

# %%
pokemon.loc[:10,['Total','HP']].to_csv('./data/pokemon_tmp.csv')

# %%
pokemon.loc[10:16,:]
# Out:
#      #                     Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 10   8                Wartortle  Water     NaN    405  59      63       80
# 11   9                Blastoise  Water     NaN    530  79      83      100
# 12   9  BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 13  10                 Caterpie    Bug     NaN    195  45      30       35
# 14  11                  Metapod    Bug     NaN    205  50      20       55
# 15  12               Butterfree    Bug  Flying    395  60      45       50
# 16  13                   Weedle    Bug  Poison    195  40      35       30
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 10       65       80     58           1      False
# 11       85      105     78           1      False
# 12      135      115     78           1      False
# 13       20       20     45           1      False
# 14       25       25     30           1      False
# 15       90       80     70           1      False
# ...

# %%
pokemon.loc[pokemon['Type 2'].isnull(), 'Type 2']
# Out:
# 4      NaN
# 5      NaN
# 9      NaN
# 10     NaN
# 11     NaN
#       ...
# 775    NaN
# 776    NaN
# 788    NaN
# 789    NaN
# 792    NaN
# Name: Type 2, Length: 386, dtype: object

# %%
pokemon.loc[pokemon["Type 2"].isnull(), "Type 2"] = pokemon.loc[pokemon["Type 2"].isnull(), "Type 1"]
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire    Fire    309  39      52       43
# 5  5                 Charmeleon   Fire    Fire    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water   Water    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
pokemon.isnull().head()
# Out:
#        #   Name  Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 0  False  False   False   False  False  False   False    False    False
# 1  False  False   False   False  False  False   False    False    False
# 2  False  False   False   False  False  False   False    False    False
# 3  False  False   False   False  False  False   False    False    False
# 4  False  False   False   False  False  False   False    False    False
#
#    Sp. Def  Speed  Generation  Legendary
# 0    False  False       False      False
# 1    False  False       False      False
# 2    False  False       False      False
# 3    False  False       False      False
# 4    False  False       False      False

# %%
apts

apts.isnull()

apts[apts.isnull() == False] #根据是否缺失选择数据
# Out:
# Beijing      55000.0
# Shanghai     60000.0
# Shenzhen     50000.0
# Hangzhou     20000.0
# Guangzhou    25000.0
# Suzhou           NaN
# Name: price, dtype: float64
# Beijing      False
# Shanghai     False
# Shenzhen     False
# Hangzhou     False
# Guangzhou    False
# Suzhou        True
# Name: price, dtype: bool
# Beijing      55000.0
# Shanghai     60000.0
# Shenzhen     50000.0
# Hangzhou     20000.0
# Guangzhou    25000.0
# Name: price, dtype: float64

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=list("abcd"))
df

df.to_csv("./data/sample.tsv", sep="\t")
# Out:
#           a         b         c         d
# 0  0.323071  0.947219  0.144171  0.310136
# 1  0.403943  0.368356  0.168294  0.699574
# 2  0.193363  0.170739  0.994702  0.900767
# 3  0.364227  0.161097  0.111391  0.802182
# 4  0.652727  0.433911  0.045037  0.229284
# 5  0.695228  0.875956  0.019091  0.061981
# 6  0.215233  0.979660  0.720615  0.229600
# 7  0.772722  0.130695  0.348514  0.395576
# 8  0.131155  0.688185  0.877242  0.314152
# 9  0.733627  0.085542  0.911184  0.224594

# %%
s = pd.Series(np.random.random(10)) * 10
s
# Out:
# 0    5.305919
# 1    2.383720
# 2    7.866976
# 3    1.464428
# 4    4.365865
# 5    3.729804
# 6    4.932838
# 7    2.489805
# 8    2.580907
# 9    4.980506
# dtype: float64

# %%
# 加法操作
df.add(s, axis=0)
# Out:
#           a         b         c         d
# 0  5.628990  6.253138  5.450091  5.616055
# 1  2.787662  2.752075  2.552014  3.083294
# 2  8.060339  8.037715  8.861678  8.767743
# 3  1.828656  1.625525  1.575819  2.266610
# 4  5.018592  4.799775  4.410902  4.595148
# 5  4.425031  4.605760  3.748894  3.791785
# 6  5.148071  5.912497  5.653453  5.162438
# 7  3.262527  2.620501  2.838319  2.885381
# 8  2.712062  3.269092  3.458149  2.895059
# 9  5.714133  5.066049  5.891691  5.205101

# %%
salaries = pd.DataFrame({
    'Name': ['BOSS', 'Jason', 'Jason', 'Han', 'BOSS', 'BOSS', 'Jason', 'BOSS'],
    'Year': [2016,2016,2016,2016,2017,2017,2017,2017],
    'Salary': [10000,2000,4000,5000,18000,25000,3000,4000],
    'Bonus': [3000,1000,1000,1200,4000,2300,500,1000]
})
salaries
# Out:
#     Name  Year  Salary  Bonus
# 0   BOSS  2016   10000   3000
# 1  Jason  2016    2000   1000
# 2  Jason  2016    4000   1000
# 3    Han  2016    5000   1200
# 4   BOSS  2017   18000   4000
# 5   BOSS  2017   25000   2300
# 6  Jason  2017    3000    500
# 7   BOSS  2017    4000   1000

# %%
group_by_name = salaries.groupby('Name')
group_by_name

# %%
# 分类与聚合
# %matplotlib inline
group_by_name.sum()
# Out:
#        Year  Salary  Bonus
# Name
# BOSS   8067   57000  10300
# Han    2016    5000   1200
# Jason  6049    9000   2500

# %%
salaries.groupby('Year', sort=True).sum()
# Out:
#       Salary  Bonus
# Year
# 2016   21000   6200
# 2017   50000   7800

# %%
salaries.groupby('Name').aggregate('sum')
# Out:
#        Year  Salary  Bonus
# Name
# BOSS   8067   57000  10300
# Han    2016    5000   1200
# Jason  6049    9000   2500

# %%
group_by_name.groups
# Out:
# {'BOSS': Int64Index([0, 4, 5, 7], dtype='int64'), 'Han': Int64Index([3], dtype='int64'), 'Jason': Int64Index([1, 2, 6], dtype='int64')}

# %%
len(group_by_name)
# Out:
# 3

# %%
salaries.groupby(['Name', 'Year']).sum()

salaries.groupby(['Year','Name']).sum()
# Out:
#             Salary  Bonus
# Name  Year
# BOSS  2016   10000   3000
#       2017   47000   7300
# Han   2016    5000   1200
# Jason 2016    6000   2000
#       2017    3000    500
#             Salary  Bonus
# Year Name
# 2016 BOSS    10000   3000
#      Han      5000   1200
#      Jason    6000   2000
# 2017 BOSS    47000   7300
#      Jason    3000    500

# %%
group_by_name_year = salaries.groupby(['Name', 'Year'])
group_by_name_year
group_by_name_year.sum()
group_by_name_year.size()
# Out:
#             Salary  Bonus
# Name  Year
# BOSS  2016   10000   3000
#       2017   47000   7300
# Han   2016    5000   1200
# Jason 2016    6000   2000
#       2017    3000    500
# Name   Year
# BOSS   2016    1
#        2017    3
# Han    2016    1
# Jason  2016    2
#        2017    1
# dtype: int64

# %%
group_by_name.mean()
# Out:
#               Year   Salary        Bonus
# Name
# BOSS   2016.750000  14250.0  2575.000000
# Han    2016.000000   5000.0  1200.000000
# Jason  2016.333333   3000.0   833.333333

# %%
group_by_name.median()
# Out:
#        Year  Salary  Bonus
# Name
# BOSS   2017   14000   2650
# Han    2016    5000   1200
# Jason  2016    3000   1000

# %%
group_by_name.describe()
# Out:
#        Year                                                                 \
#       count         mean      std     min      25%     50%     75%     max
# Name
# BOSS    4.0  2016.750000  0.50000  2016.0  2016.75  2017.0  2017.0  2017.0
# Han     1.0  2016.000000      NaN  2016.0  2016.00  2016.0  2016.0  2016.0
# Jason   3.0  2016.333333  0.57735  2016.0  2016.00  2016.0  2016.5  2017.0
#
#       Salary           ...                   Bonus                            \
#        count     mean  ...      75%      max count         mean          std
# Name                   ...
# BOSS     4.0  14250.0  ...  19750.0  25000.0   4.0  2575.000000  1260.621540
# Han      1.0   5000.0  ...   5000.0   5000.0   1.0  1200.000000          NaN
# Jason    3.0   3000.0  ...   3500.0   4000.0   3.0   833.333333   288.675135
#
#
#           min     25%     50%     75%     max
# Name
# BOSS   1000.0  1975.0  2650.0  3250.0  4000.0
# Han    1200.0  1200.0  1200.0  1200.0  1200.0
# ...

# %%
group_by_name.groups

for key, value in group_by_name:
    print(key)
    print(value)
# Out:
# {'BOSS': Int64Index([0, 4, 5, 7], dtype='int64'), 'Han': Int64Index([3], dtype='int64'), 'Jason': Int64Index([1, 2, 6], dtype='int64')}
# BOSS
#    Name  Year  Salary  Bonus
# 0  BOSS  2016   10000   3000
# 4  BOSS  2017   18000   4000
# 5  BOSS  2017   25000   2300
# 7  BOSS  2017    4000   1000
# Han
#   Name  Year  Salary  Bonus
# 3  Han  2016    5000   1200
# Jason
#     Name  Year  Salary  Bonus
# 1  Jason  2016    2000   1000
# 2  Jason  2016    4000   1000
# 6  Jason  2017    3000    500

# %%
group_by_name.get_group('Jason')

type(group_by_name.get_group('Jason'))
# Out:
#     Name  Year  Salary  Bonus
# 1  Jason  2016    2000   1000
# 2  Jason  2016    4000   1000
# 6  Jason  2017    3000    500
# <class 'pandas.core.frame.DataFrame'>

# %%
group_by_name.agg([np.sum, np.std, np.mean])
# Out:
#        Year                       Salary                      Bonus  \
#         sum      std         mean    sum          std   mean    sum
# Name
# BOSS   8067  0.50000  2016.750000  57000  9178.779875  14250  10300
# Han    2016      NaN  2016.000000   5000          NaN   5000   1200
# Jason  6049  0.57735  2016.333333   9000  1000.000000   3000   2500
#
#
#                std         mean
# Name
# BOSS   1260.621540  2575.000000
# Han            NaN  1200.000000
# Jason   288.675135   833.333333

# %%
group_by_name.agg({'Salary': np.mean, 'Bonus':np.std})
# Out:
#        Salary        Bonus
# Name
# BOSS    14250  1260.621540
# Han      5000          NaN
# Jason    3000   288.675135

# %%
group_by_name.agg({"Bonus": np.sum, "Salary": np.sum, "Year": (lambda x: list(x)[0])})
# Out:
#        Bonus  Salary  Year
# Name
# BOSS   10300   57000  2016
# Han     1200    5000  2016
# Jason   2500    9000  2016

# %%
nvda = pd.read_csv('./data/NVDA.csv', index_col=0, parse_dates=[0])
nvda.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1999-01-22  1.750000  1.953125  1.552083  1.640625   1.523430  67867200
# 1999-01-25  1.770833  1.833333  1.640625  1.812500   1.683028  12762000
# 1999-01-26  1.833333  1.869792  1.645833  1.671875   1.552448   8580000
# 1999-01-27  1.677083  1.718750  1.583333  1.666667   1.547611   6109200
# 1999-01-28  1.666667  1.677083  1.651042  1.661458   1.542776   5688000

# %%
nvda.index
# Out:
# DatetimeIndex(['1999-01-22', '1999-01-25', '1999-01-26', '1999-01-27',
#                '1999-01-28', '1999-01-29', '1999-02-01', '1999-02-02',
#                '1999-02-03', '1999-02-04',
#                ...
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20'],
#               dtype='datetime64[ns]', name='Date', length=4654, freq=None)

# %%
nvda.groupby(nvda.index.year).mean()
# Out:
#             Open        High         Low       Close   Adj Close        Volume
# Date
# 1999    1.950782    2.007317    1.883559    1.947230    1.808134  6.433220e+06
# 2000    8.781084    9.222697    8.360522    8.778826    8.151729  1.104182e+07
# 2001   13.091254   13.600750   12.680548   13.181552   12.239956  2.782387e+07
# 2002    9.690344    9.955093    9.344391    9.614749    8.927940  3.168655e+07
# 2003    5.902434    6.042659    5.764960    5.900344    5.478865  2.430220e+07
# 2004    6.484735    6.608810    6.353558    6.465913    6.004034  1.706331e+07
# 2005    9.512381    9.659656    9.353175    9.513823    8.834223  1.542825e+07
# 2006   18.057902   18.425126   17.720279   18.095963   16.803316  1.534446e+07
# 2007   27.762045   28.251673   27.206056   27.724542   25.744098  1.514562e+07
# 2008   16.004308   16.426245   15.521462   15.945613   14.806572  2.022721e+07
# 2009   11.825119   12.114762   11.565952   11.850873   11.004331  1.919821e+07
# ...

# %%
# 归一化操作
zscore = lambda x:(x-x.mean())/x.std()
transform = nvda.groupby(nvda.index.year).transform(zscore)
transform.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1999-01-22 -0.340955 -0.088217 -0.579850 -0.510124  -0.510124  7.544438
# 1999-01-25 -0.305578 -0.283222 -0.424964 -0.224161  -0.224161  0.777210
# 1999-01-26 -0.199444 -0.223871 -0.415854 -0.458130  -0.458131  0.263637
# 1999-01-27 -0.464778 -0.469747 -0.525185 -0.466795  -0.466798 -0.039791
# 1999-01-28 -0.482465 -0.537575 -0.406741 -0.475462  -0.475461 -0.091517

# %%
transform = nvda.groupby(nvda.index.year).apply(zscore)
transform.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1999-01-22 -0.340955 -0.088217 -0.579850 -0.510124  -0.510124  7.544438
# 1999-01-25 -0.305578 -0.283222 -0.424964 -0.224161  -0.224161  0.777210
# 1999-01-26 -0.199444 -0.223871 -0.415854 -0.458130  -0.458131  0.263637
# 1999-01-27 -0.464778 -0.469747 -0.525185 -0.466795  -0.466798 -0.039791
# 1999-01-28 -0.482465 -0.537575 -0.406741 -0.475462  -0.475461 -0.091517

# %%
compare = pd.DataFrame({
    "Original Adj Close": nvda["Adj Close"], 
    "Transormed Adj Close": transform["Adj Close"]
})
compare.plot()

# %%
price_range = lambda x: x.max() - x.min()
nvda.groupby(nvda.index.year).transform(price_range).head()
# Out:
#                 Open     High       Low     Close  Adj Close      Volume
# Date
# 1999-01-22  2.552084  2.53125  2.510417  2.546875   2.364945  67375200.0
# 1999-01-25  2.552084  2.53125  2.510417  2.546875   2.364945  67375200.0
# 1999-01-26  2.552084  2.53125  2.510417  2.546875   2.364945  67375200.0
# 1999-01-27  2.552084  2.53125  2.510417  2.546875   2.364945  67375200.0
# 1999-01-28  2.552084  2.53125  2.510417  2.546875   2.364945  67375200.0

# %%
nvda.groupby(nvda.index.year).transform("max").head()
# Out:
#                 Open      High      Low     Close  Adj Close    Volume
# Date
# 1999-01-22  3.947917  3.953125  3.84375  3.911458   3.632052  67867200
# 1999-01-25  3.947917  3.953125  3.84375  3.911458   3.632052  67867200
# 1999-01-26  3.947917  3.953125  3.84375  3.911458   3.632052  67867200
# 1999-01-27  3.947917  3.953125  3.84375  3.911458   3.632052  67867200
# 1999-01-28  3.947917  3.953125  3.84375  3.911458   3.632052  67867200

# %%
s = pd.Series([1,1,2,2,2,3,4,4,5])
s
s.groupby(s).groups
s.groupby(s).filter(lambda x: x.sum() > 4)
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    2
# 5    3
# 6    4
# 7    4
# 8    5
# dtype: int64
# {1: Int64Index([0, 1], dtype='int64'), 2: Int64Index([2, 3, 4], dtype='int64'), 3: Int64Index([5], dtype='int64'), 4: Int64Index([6, 7], dtype='int64'), 5: Int64Index([8], dtype='int64')}
# 2    2
# 3    2
# 4    2
# 6    4
# 7    4
# 8    5
# dtype: int64

# %%
nvda.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 1999-01-22  1.750000  1.953125  1.552083  1.640625   1.523430  67867200
# 1999-01-25  1.770833  1.833333  1.640625  1.812500   1.683028  12762000
# 1999-01-26  1.833333  1.869792  1.645833  1.671875   1.552448   8580000
# 1999-01-27  1.677083  1.718750  1.583333  1.666667   1.547611   6109200
# 1999-01-28  1.666667  1.677083  1.651042  1.661458   1.542776   5688000

# %%
nvda.groupby([nvda.index.year, nvda.index.month]).filter(lambda x: x["Adj Close"].mean() > 50)


nvda.groupby([nvda.index.year, nvda.index.month, nvda.index.day]).filter(lambda x:  x["Adj Close"]>100)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-07-01   46.750000   47.360001   46.500000   46.660000   46.397064
# 2016-07-05   46.400002   47.430000   46.029999   47.349998   47.083176
# 2016-07-06   47.020000   47.930000   46.779999   47.650002   47.381493
# 2016-07-07   47.970001   49.060001   47.750000   48.889999   48.614498
# 2016-07-08   49.410000   51.090000   49.220001   50.849998   50.563454
# ...                ...         ...         ...         ...         ...
# 2017-07-14  161.289993  165.009995  161.009995  164.949997  164.949997
# 2017-07-17  166.330002  167.500000  161.750000  164.250000  164.250000
# 2017-07-18  161.779999  166.550003  161.300003  165.960007  165.960007
# 2017-07-19  166.330002  167.399994  164.610001  165.100006  165.100006
# 2017-07-20  165.929993  167.509995  163.910004  167.500000  167.500000
#
#               Volume
# Date
# 2016-07-01   5462200
# 2016-07-05   9277100
# 2016-07-06   6827600
# ...

# %%
nvda.groupby([nvda.index.year, nvda.index.month]).groups
# Out:
# {(1999, 1): DatetimeIndex(['1999-01-22', '1999-01-25', '1999-01-26', '1999-01-27',
#                '1999-01-28', '1999-01-29'],
#               dtype='datetime64[ns]', name='Date', freq=None), (1999, 2): DatetimeIndex(['1999-02-01', '1999-02-02', '1999-02-03', '1999-02-04',
#                '1999-02-05', '1999-02-08', '1999-02-09', '1999-02-10',
#                '1999-02-11', '1999-02-12', '1999-02-16', '1999-02-17',
#                '1999-02-18', '1999-02-19', '1999-02-22', '1999-02-23',
#                '1999-02-24', '1999-02-25', '1999-02-26'],
#               dtype='datetime64[ns]', name='Date', freq=None), (1999, 3): DatetimeIndex(['1999-03-01', '1999-03-02', '1999-03-03', '1999-03-04',
#                '1999-03-05', '1999-03-08', '1999-03-09', '1999-03-10',
#                '1999-03-11', '1999-03-12', '1999-03-15', '1999-03-16',
#                '1999-03-17', '1999-03-18', '1999-03-19', '1999-03-22',
#                '1999-03-23', '1999-03-24', '1999-03-25', '1999-03-26',
# ...

# %%
# 多表合并与拼接
df1 = pd.DataFrame({'apts': [55000, 60000],
                   'cars': [200000, 300000],},
                  index = ['Shanghai', 'Beijing']
                  )
df1

df2 = pd.DataFrame({'cars': [150000, 120000],
                    'apts': [25000, 20000],
                   },
                  index = ['Hangzhou', 'Nanjing'])
df2

df3 = pd.DataFrame({'apts': [30000, 10000],
                   'cars': [180000, 100000],'mar': [180000, 100000]},
                  index = ['Guangzhou', 'Chongqing'])
df3
# Out:
#            apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000
#             cars   apts
# Hangzhou  150000  25000
# Nanjing   120000  20000
#             apts    cars     mar
# Guangzhou  30000  180000  180000
# Chongqing  10000  100000  100000

# %%
frames = [df1, df2, df3] 
frames
result = pd.concat([df1,df2,df3])
type(frames)
result
# Out:
# [           apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000,             cars   apts
# Hangzhou  150000  25000
# Nanjing   120000  20000,             apts    cars     mar
# Guangzhou  30000  180000  180000
# Chongqing  10000  100000  100000]
# <class 'list'>
#             apts    cars       mar
# Shanghai   55000  200000       NaN
# Beijing    60000  300000       NaN
# Hangzhou   25000  150000       NaN
# Nanjing    20000  120000       NaN
# Guangzhou  30000  180000  180000.0
# Chongqing  10000  100000  100000.0

# %%
result2 = pd.concat(frames, keys=['x', 'y', 'z'], sort=False)
result2
# Out:
#               apts    cars       mar
# x Shanghai   55000  200000       NaN
#   Beijing    60000  300000       NaN
# y Hangzhou   25000  150000       NaN
#   Nanjing    20000  120000       NaN
# z Guangzhou  30000  180000  180000.0
#   Chongqing  10000  100000  100000.0

# %%
result2.loc['y', 'Hangzhou']
# Out:
# apts     25000.0
# cars    150000.0
# mar          NaN
# Name: (y, Hangzhou), dtype: float64

# %%
df4 = pd.DataFrame({'salaries': [10000, 30000, 30000, 20000, 15000]},
                  index = ['Suzhou', 'Beijing', 'Shanghai', 'Guangzhou', 'Tianjin'])
df4
# Out:
#            salaries
# Suzhou        10000
# Beijing       30000
# Shanghai      30000
# Guangzhou     20000
# Tianjin       15000

# %%
# 添加列，空值设为NaN
result3 = pd.concat([result, df4], axis=1, sort=False)
result3
# Out:
#               apts      cars       mar  salaries
# Shanghai   55000.0  200000.0       NaN   30000.0
# Beijing    60000.0  300000.0       NaN   30000.0
# Hangzhou   25000.0  150000.0       NaN       NaN
# Nanjing    20000.0  120000.0       NaN       NaN
# Guangzhou  30000.0  180000.0  180000.0   20000.0
# Chongqing  10000.0  100000.0  100000.0       NaN
# Suzhou         NaN       NaN       NaN   10000.0
# Tianjin        NaN       NaN       NaN   15000.0

# %%
# 添加行
result3 = pd.concat([result, df4], axis=0, sort=False)
result3
# Out:
#               apts      cars       mar  salaries
# Shanghai   55000.0  200000.0       NaN       NaN
# Beijing    60000.0  300000.0       NaN       NaN
# Hangzhou   25000.0  150000.0       NaN       NaN
# Nanjing    20000.0  120000.0       NaN       NaN
# Guangzhou  30000.0  180000.0  180000.0       NaN
# Chongqing  10000.0  100000.0  100000.0       NaN
# Suzhou         NaN       NaN       NaN   10000.0
# Beijing        NaN       NaN       NaN   30000.0
# Shanghai       NaN       NaN       NaN   30000.0
# Guangzhou      NaN       NaN       NaN   20000.0
# Tianjin        NaN       NaN       NaN   15000.0

# %%
# 内连接
result3 = pd.concat([result, df4], axis=1, join='inner')
result3
# Out:
#             apts    cars       mar  salaries
# Shanghai   55000  200000       NaN     30000
# Beijing    60000  300000       NaN     30000
# Guangzhou  30000  180000  180000.0     20000

# %%
df1
df2
df3 = df1.append(df2, sort=False)
type(df3)
df3
# Out:
#            apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000
#             cars   apts
# Hangzhou  150000  25000
# Nanjing   120000  20000
# <class 'pandas.core.frame.DataFrame'>
#            apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000
# Hangzhou  25000  150000
# Nanjing   20000  120000

# %%
df1
df4
df1.append(df4, sort=False)
# Out:
#            apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000
#            salaries
# Suzhou        10000
# Beijing       30000
# Shanghai      30000
# Guangzhou     20000
# Tianjin       15000
#               apts      cars  salaries
# Shanghai   55000.0  200000.0       NaN
# Beijing    60000.0  300000.0       NaN
# Suzhou         NaN       NaN   10000.0
# Beijing        NaN       NaN   30000.0
# Shanghai       NaN       NaN   30000.0
# Guangzhou      NaN       NaN   20000.0
# Tianjin        NaN       NaN   15000.0

# %%
s1 = pd.Series([60, 50], index=['Shanghai', 'Beijing'], name='meal')
s1
df1
# Out:
# Shanghai    60
# Beijing     50
# Name: meal, dtype: int64
#            apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000

# %%
pd.concat([df1, s1], axis=1)
pd.concat([df1, s1], axis=0)
# Out:
#            apts    cars  meal
# Shanghai  55000  200000    60
# Beijing   60000  300000    50
#              apts      cars     0
# Shanghai  55000.0  200000.0   NaN
# Beijing   60000.0  300000.0   NaN
# Shanghai      NaN       NaN  60.0
# Beijing       NaN       NaN  50.0

# %%
s2 = pd.Series([18000, 12000], index=['apts', 'cars'], name='Xiamen') #注意这里的name是必须要有的，因为要用作Index。
s2
df1
df1.append(s2)
# Out:
# apts    18000
# cars    12000
# Name: Xiamen, dtype: int64
#            apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000
#            apts    cars
# Shanghai  55000  200000
# Beijing   60000  300000
# Xiamen    18000   12000

# %%
df1 = pd.DataFrame({'apts': [55000, 60000, 58000],
                   'cars': [200000, 300000,250000],
                  'city': ['Shanghai', 'Beijing','Shenzhen']})
df1
df4 = pd.DataFrame({'salaries': [10000, 30000, 30000, 20000, 15000],
                  'city': ['Suzhou', 'Beijing', 'Shanghai', 'Guangzhou', 'Tianjin']})
df4
# Out:
#     apts    cars      city
# 0  55000  200000  Shanghai
# 1  60000  300000   Beijing
# 2  58000  250000  Shenzhen
#    salaries       city
# 0     10000     Suzhou
# 1     30000    Beijing
# 2     30000   Shanghai
# 3     20000  Guangzhou
# 4     15000    Tianjin

# %%
pd.merge(df1, df4)
# Out:
#     apts    cars      city  salaries
# 0  55000  200000  Shanghai     30000
# 1  60000  300000   Beijing     30000

# %%
# 外键
# 默认为inner方式
pd.merge(df1, df4, on='city')
pd.merge(df1, df4, on='city', how='inner')
# Out:
#     apts    cars      city  salaries
# 0  55000  200000  Shanghai     30000
# 1  60000  300000   Beijing     30000
#     apts    cars      city  salaries
# 0  55000  200000  Shanghai     30000
# 1  60000  300000   Beijing     30000

# %%
# 外连接
result = pd.merge(df1, df4, on='city', how='outer')
result
# Out:
#       apts      cars       city  salaries
# 0  55000.0  200000.0   Shanghai   30000.0
# 1  60000.0  300000.0    Beijing   30000.0
# 2  58000.0  250000.0   Shenzhen       NaN
# 3      NaN       NaN     Suzhou   10000.0
# 4      NaN       NaN  Guangzhou   20000.0
# 5      NaN       NaN    Tianjin   15000.0

# %%
result = pd.merge(df1, df4, on='city', how='right')
result
# Out:
#       apts      cars       city  salaries
# 0  55000.0  200000.0   Shanghai     30000
# 1  60000.0  300000.0    Beijing     30000
# 2      NaN       NaN     Suzhou     10000
# 3      NaN       NaN  Guangzhou     20000
# 4      NaN       NaN    Tianjin     15000

# %%
result = pd.merge(df1, df4, on='city', how='left')
result
# Out:
#     apts    cars      city  salaries
# 0  55000  200000  Shanghai   30000.0
# 1  60000  300000   Beijing   30000.0
# 2  58000  250000  Shenzhen       NaN

# %%
df1.set_index('city')
df4.set_index('city')
pd.concat([df1.set_index("city"), df4.set_index('city')], sort=False, axis=1, join="inner")
# Out:
#            apts    cars
# city
# Shanghai  55000  200000
# Beijing   60000  300000
# Shenzhen  58000  250000
#            salaries
# city
# Suzhou        10000
# Beijing       30000
# Shanghai      30000
# Guangzhou     20000
# Tianjin       15000
#            apts    cars  salaries
# city
# Shanghai  55000  200000     30000
# Beijing   60000  300000     30000

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                     'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                     'value': [5, 6, 7, 8]})
df1
df2
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7

# %%
df1.merge(df2, left_on='lkey', right_on='rkey',suffixes=('_left', '_right'))
# Out:
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  foo           5  foo            5
# 3  foo           5  foo            8
# 4  bar           2  bar            6
# 5  baz           3  baz            7

# %%
# 合并时数据帧重叠会发生异常
try:
    df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=(False, False))
except(ValueError):
    print("产生异常！！！")
# Out:
# 产生异常！！！
